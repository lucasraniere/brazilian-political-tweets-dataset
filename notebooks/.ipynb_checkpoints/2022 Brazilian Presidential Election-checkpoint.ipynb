# %%
import sys
sys.path.insert(1, '../')

import pandas as pd
from source import preprocess as pp
import os

DATA_PATH = '../data/2022-brazilian-presidential/'

# %% [markdown]
# ### __Files__

# %%
# loading file names
file_list = os.listdir(DATA_PATH)
file_list.sort()
search_terms = pd.Series([file[11:-8] for file in file_list])
search_dates = pd.Series([file[0:10] for file in file_list])
# displaying the number of searched terms (total and unique)
print((
    'Number of search terms: {}\n'
    'Number of unique search terms: {}'
).format(
    search_terms.shape[0],
    search_terms.unique().shape[0]
))
# Out:
# Number of search terms: 104
# Number of unique search terms: 91

# %%
dates_n_terms = pd.DataFrame({
    'date': search_dates,
    'search_terms': search_terms
})
# displaying search dates and terms
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(dates_n_terms)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>search_terms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-08-01</td>
#       <td>BOLSONARO NÃO TRABALHA</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-08-09</td>
#       <td>NÃO VOTE EM RACISTA</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-08-22</td>
#       <td>#BolsonaroNoJN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2022-08-22</td>
#       <td>#Eleicoes2022</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2022-08-22</td>
#       <td>#ForaBolsonaro</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2022-08-22</td>
#       <td>#GloboLixo</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2022-08-25</td>
#       <td>#LADRAONOJN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2022-08-25</td>
#       <td>BOBO DA CORTE</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2022-08-25</td>
#       <td>Faz o L</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2022-08-28</td>
#       <td>#DebateNaBand</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2022-09-23</td>
#       <td>DINHEIRO VIVO</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2022-09-23</td>
#       <td>Faltam 9</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2022-09-23</td>
#       <td>SÓ CIRO VENCE LULA</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2022-09-24</td>
#       <td>#DebateNoSBT</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2022-09-24</td>
#       <td>BOLSONARO CORRUPTO</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2022-09-24</td>
#       <td>MEU VOTO NÃO ANISTIA BANDIDO</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2022-09-25</td>
#       <td>#EsseÉMeuVoto</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>2022-09-25</td>
#       <td>#LulaNo1ºTurno</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2022-09-25</td>
#       <td>Faltam 7</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2022-09-26</td>
#       <td>#BrasilDaEsperança</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2022-09-26</td>
#       <td>#BrasilVota22</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>2022-09-26</td>
#       <td>#CiroManifestoANacao</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>2022-09-26</td>
#       <td>#CiroNoFlow</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2022-09-26</td>
#       <td>#LulaNo1ºTurno</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2022-09-26</td>
#       <td>#TiraGomes</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>2022-09-26</td>
#       <td>AGORA É LULA</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2022-09-26</td>
#       <td>BRASIL RESISTE</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2022-09-26</td>
#       <td>Bolsonaro 31%</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2022-09-26</td>
#       <td>Faltam 6</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2022-09-26</td>
#       <td>LULA NO PRIMEIRO TURNO</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>2022-09-26</td>
#       <td>Lula 48%</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>2022-09-28</td>
#       <td>#DebateNaGlobo</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>2022-10-30</td>
#       <td>#BolsonaroReeleito2️⃣2️⃣</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>2022-10-30</td>
#       <td>#LulaPresidente1️⃣3️⃣</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>2022-10-30</td>
#       <td>Polícia Rodoviária Federal</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>2022-10-31</td>
#       <td>#LulaPresidente1️⃣3️⃣</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>2022-10-31</td>
#       <td>Apertei 13</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>2022-10-31</td>
#       <td>DEIXEM O NORDESTE VOTAR</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>2022-11-04</td>
#       <td>400 BILHÕES</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>2022-11-04</td>
#       <td>BOLSONARO QUEBROU O BRASIL</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>2022-11-04</td>
#       <td>JAIR QUEBROU O BRASIL</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td
</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>MEU VOTO NÃO ANISTIA BANDIDO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#EsseÉMeuVoto</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Faltam 7</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#BrasilDaEsperança</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#BrasilVota22</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#CiroManifestoANacao</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#CiroNoFlow</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#TiraGomes</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>AGORA É LULA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BRASIL RESISTE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Bolsonaro 31%</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Faltam 6</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>LULA NO PRIMEIRO TURNO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Lula 48%</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#DebateNaGlobo</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#BolsonaroReeleito2️⃣2️⃣</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Polícia Rodoviária Federal</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Apertei 13</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>DEIXEM O NORDESTE VOTAR</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>400 BILHÕES</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BOLSONARO QUEBROU O BRASIL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>JAIR QUEBROU O BRASIL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Rombo de 400</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#STFVergonhaMundial</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BOLSONARO LADRÃO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#Caminhoneiros</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>APOIO LULA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>QG DO GOLPE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BRAGA NETO NA CADEIA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>RENUNCIA BOLSONARO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#BolsonaroReeleito</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Bolsonaro 51%</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>O LULA TÁ ELEITO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Alexandre de Morais</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Artigo 142</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Deu 22</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>EU AUTORIZO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Faz o 22</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Xandão</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>É 22</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#EuAutorizoPresidente</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Bananinha</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>HAARP</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>JAIR SAQUEOU O BRASIL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Paquita da Ditadura</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BOLSONARO INIMIGO DA EDUCAÇÃO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>DIPLOMAÇÃO DO LULA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Votei 22</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#DiplomacaoDoLula</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>#LulaEoBrasilSubindoARampa</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Armação</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Brasília</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Cacique</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Capitólio</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>LULA PRESIDENTE</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Manifestantes</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Polícia Federal</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>bolsonaristas</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Índio</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Bolsonaristas</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Fora Bolsonaro</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Patriotas</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Terroristas</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Faltam 72</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ACABOU BOLSONARO</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>JAIR EMBORA</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Lula</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
file_example = pd.read_parquet(DATA_PATH+file_list[0])
file_example.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_at</th>
#       <th>tweet_id</th>
#       <th>tweet_content</th>
#       <th>user</th>
#       <th>user_info</th>
#       <th>has_mention</th>
#       <th>mentions</th>
#       <th>is_reply</th>
#       <th>reply_to</th>
#       <th>is_quote</th>
#       <th>quoted_from</th>
#       <th>is_retweet</th>
#       <th>retweeted_from</th>
#       <th>hashtags</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-08-04 02:52:05</td>
#       <td>1555023739988971521</td>
#       <td>Passou 4 anos andando de moto e jetski enquant...</td>
#       <td>zitelli_carlos</td>
#       <td>{'id': 721831120120188928, 'name': 'Carlos Zit...</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>{'user': 'tesoureiros', 'user_id': 10714084365...</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-08-04 02:48:40</td>
#       <td>1555022883138813952</td>
#       <td>Os assuntos do momento: \nCORNOS COM BOLSONARO...</td>
#       <td>MarcosTil</td>
#       <td>{'id': 87421436, 'name': 'Marcos Til', 'descri...</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>{'user': 'detremura', 'user_id': 102826672, 't...</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-08-04 02:48:09</td>
#       <td>1555022751106228226</td>
#       <td>Em 3 anos e meio Bolsonaro trabalhou menos de ...</td>
#       <td>marialo71834768</td>
#       <td>{'id': 1535023761241657351, 'name': 'Patriotis...</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>{'user': 'ThiagoResiste', 'user_id': 127077402...</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2022-08-04 02:41:05</td>
#       <td>1555020974847819778</td>
#       <td>Ah, mas o problema da crise econômica é do 'fi...</td>
#       <td>desestressada1</td>
#       <td>{'id': 1090045777395761154, 'name': 'desestres...</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>{'user': 'PedroRonchi2', 'user_id': 1097073004...</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2022-08-04 02:33:33</td>
#       <td>1555019075117621248</td>
#       <td>Em 3 anos e meio Bolsonaro trabalhou menos de ...</td>
#       <td>Edu64986869</td>
#       <td>{'id': 1521688957720965120, 'name': 'Edu', 'de...</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>{'user': 'ThiagoResiste', 'user_id': 127077402...</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
file_example.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21380 entries, 0 to 21379
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_at      21380 non-null  object
#  1   tweet_id        21380 non-null  int64
#  2   tweet_content   21380 non-null  object
#  3   user            21380 non-null  object
#  4   user_info       21380 non-null  object
#  5   has_mention     21380 non-null  bool
#  6   mentions        3477 non-null   object
#  7   is_reply        21380 non-null  bool
#  8   reply_to        2686 non-null   object
#  9   is_quote        21380 non-null  bool
#  10  quoted_from     1348 non-null   object
#  11  is_retweet      21380 non-null  bool
#  12  retweeted_from  16312 non-null  object
#  13  hashtags        1114 non-null   object
# dtypes: bool(4), int64(1), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# ### __Quantitative Analysis__

# %%
tweets = pd.DataFrame()

for file in file_list:
    df = pd.read_parquet(os.path.join(DATA_PATH, file))
    tweets = pd.concat([tweets, df], ignore_index=True)

tweets.drop_duplicates(keep='first', inplace=True, ignore_index=True)

# %% [markdown]
# #### __Textual Preprocessing__
#
#
#
# - URL removal
# - Mention removal (@user)
# - Hashtags removal (#removal)
# - Punctuation removal
# - Emoji removal
# - Removing unwanted white spaces
#     - Trailing spaces
#     - Multiple spaces
#     - Line breaks
# - Text Normalization
#     - Lowercase
#     - Stopwords removal

# %%
tweets['preproc_tweets'] = tweets['tweet_content'].map(lambda x: pp.preprocess_text(x))
tweets.to_parquet(os.path.join(DATA_PATH, '2022_all_tweets'), index=False)
tweets_unique_preproc = tweets['preproc_tweet'].unique().shape[0]
tweets_unique = tweets['tweet_content'].unique().shape[0]

# %%
display(pd.DataFrame(
    index = ['tweets_total', 'tweets_unique', 'tweets_preproc_unique'],
    data = [tweets.shape[0], tweets_unique, tweets_unique_preproc]
))
# Out:
#                              0
# tweets_total           6676993
# tweets_unique          1262224
# tweets_preproc_unique   920830

# %%
#users

# %%
users = pd.Series()
tweets = pd.DataFrame()
days = {}
terms = {}

# %%
for file in file_list:
    df = pd.read_parquet(DATA_PATH+file)
    users = pd.concat([users, df['user']])
    tweets = pd.concat([tweets, df])
    tweets.drop_duplicates
    day = file[:10]
    term = file[11:-8]
    if day not in days.keys():
        days[day] = tweets
    else:
        days[day] = pd.concat([days[day], tweets]).drop_duplicates(ignore_index=True)
    if term not in terms.keys():
        terms[term] = tweets
    else:
        terms[term] = pd.concat([terms[term], tweets]).drop_duplicates(ignore_index=True)

# %%
tweets.shape

# %%
tweets.drop_duplicates(inplace=True, ignore_index=True)
tweets_unique = tweets['preproc_tweet'].unique().shape[0]

# %%
for key in days.keys():
    tweets = days[key].drop_duplicates()
    tweets_unique = tweets['']
    days[keys] = {
        
    }

# %%
import sys
sys.path.insert(1, '../')
import pandas as pd
from source import preprocess as pp
import os

DATA_PATH = '../data/2022-brazilian-presidential/'

# %% [markdown]
# ### __Files__

# %%
# loading file names
file_list = [file for file in os.listdir(DATA_PATH) if file.startswith('2022-')]
file_list.sort()
search_terms = pd.Series([file[11:-8] for file in file_list])
search_dates = pd.Series([file[0:10] for file in file_list])
# displaying the number of searched terms (total and unique)
print((
    'Number of search terms: {}\n'
    'Number of unique search terms: {}'
).format(
    search_terms.shape[0],
    search_terms.unique().shape[0]
))
# Out:
# Number of search terms: 104
# Number of unique search terms: 91

# %%
dates_n_terms = pd.DataFrame({
    'date': search_dates,
    'search_terms': search_terms
})
# displaying search dates and terms
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(dates_n_terms)
# Out:
#            date                     search_terms
# 0    2022-08-01          BOLSONARO NÃO TRABALHA
# 1    2022-08-09             NÃO VOTE EM RACISTA
# 2    2022-08-22                   #BolsonaroNoJN
# 3    2022-08-22                    #Eleicoes2022
# 4    2022-08-22                   #ForaBolsonaro
# 5    2022-08-22                       #GloboLixo
# 6    2022-08-25                      #LADRAONOJN
# 7    2022-08-25                    BOBO DA CORTE
# 8    2022-08-25                          Faz o L
# 9    2022-08-28                    #DebateNaBand
# 10   2022-09-23                    DINHEIRO VIVO
# 11   2022-09-23                         Faltam 9
# 12   2022-09-23              SÓ CIRO VENCE LULA
# 13   2022-09-24                     #DebateNoSBT
# 14   2022-09-24               BOLSONARO CORRUPTO
# 15   2022-09-24    MEU VOTO NÃO ANISTIA BANDIDO
# 16   2022-09-25                   #EsseÉMeuVoto
# 17   2022-09-25                   #LulaNo1ºTurno
# 18   2022-09-25                         Faltam 7
# 19   2022-09-26              #BrasilDaEsperança
# 20   2022-09-26                    #BrasilVota22
# 21   2022-09-26             #CiroManifestoANacao
# 22   2022-09-26                      #CiroNoFlow
# 23   2022-09-26                   #LulaNo1ºTurno
# 24   2022-09-26                       #TiraGomes
# 25   2022-09-26                    AGORA É LULA
# 26   2022-09-26                   BRASIL RESISTE
# 27   2022-09-26                    Bolsonaro 31%
# 28   2022-09-26                         Faltam 6
# 29   2022-09-26           LULA NO PRIMEIRO TURNO
# 30   2022-09-26                         Lula 48%
# 31   2022-09-28                   #DebateNaGlobo
# 32   2022-10-30         #BolsonaroReeleito2️⃣2️⃣
# 33   2022-10-30            #LulaPresidente1️⃣3️⃣
# 34   2022-10-30     Polícia Rodoviária Federal
# 35   2022-10-31            #LulaPresidente1️⃣3️⃣
# 36   2022-10-31                       Apertei 13
# 37   2022-10-31          DEIXEM O NORDESTE VOTAR
# 38   2022-11-04                     400 BILHÕES
# 39   2022-11-04       BOLSONARO QUEBROU O BRASIL
# 40   2022-11-04            JAIR QUEBROU O BRASIL
# 41   2022-11-04                     Rombo de 400
# 42   2022-11-06                    NÓS VENCEMOS
# 43   2022-11-14              #STFVergonhaMundial
# 44   2022-11-14          BOLSONARO NÃO TRABALHA
# 45   2022-11-15                     PERDEU MANÉ
# 46   2022-11-16                     PERDEU MANÉ
# 47   2022-11-17                BOLSONARO LADRÃO
# 48   2022-11-17          ORÇAMENTO SECRETO NÃO
# 49   2022-11-18                   #Caminhoneiros
# 50   2022-11-18                       APOIO LULA
# 51   2022-11-18                      QG DO GOLPE
# 52   2022-11-19             BRAGA NETO NA CADEIA
# 53   2022-11-19               RENUNCIA BOLSONARO
# 54   2022-11-22               #BolsonaroReeleito
# 55   2022-11-22                    Bolsonaro 51%
# 56   2022-11-22                O LULA TÁ ELEITO
# 57   2022-11-23              Alexandre de Morais
# 58   2022-11-23                       Artigo 142
# 59   2022-11-23                           Deu 22
# 60   2022-11-23                      EU AUTORIZO
# 61   2022-11-23                            É 22
# 62   2022-11-23                         Faz o 22
# 63   2022-11-23                          Xandão
# 64   2022-11-24            #EuAutorizoPresidente
# 65   2022-11-28                Eduardo Bolsonaro
# 66   2022-11-29                Eduardo Bolsonaro
# 67   2022-11-30                        Bananinha
# 68   2022-11-30                Eduardo Bolsonaro
# 69   2022-11-30                            HAARP
# 70   2022-11-30            JAIR SAQUEOU O BRASIL
# 71   2022-11-30              Paquita da Ditadura
# 72   2022-12-02          ORÇAMENTO SECRETO NÃO
# 73   2022-12-06                 #PagueMinhaBolsa
# 74   2022-12-06                            CAPES
# 75   2022-12-07                 #PagueMinhaBolsa
# 76   2022-12-07                            CAPES
# 77   2022-12-07          ORÇAMENTO SECRETO NÃO
# 78   2022-12-08  BOLSONARO INIMIGO DA EDUCAÇÃO
# 79   2022-12-11             DIPLOMAÇÃO DO LULA
# 80   2022-12-11                         Votei 22
# 81   2022-12-12                #DiplomacaoDoLula
# 82   2022-12-12       #LulaEoBrasilSubindoARampa
# 83   2022-12-12                        Armação
# 84   2022-12-12                        Brasília
# 85   2022-12-12                          Cacique
# 86   2022-12-12                       Capitólio
# 87   2022-12-12                      Infiltrados
# 88   2022-12-12                           Índio
# 89   2022-12-12                  LULA PRESIDENTE
# 90   2022-12-12                    Manifestantes
# 91   2022-12-12                    NÓS VENCEMOS
# 92   2022-12-12                 Polícia Federal
# 93   2022-12-12                    bolsonaristas
# 94   2022-12-13                    Bolsonaristas
# 95   2022-12-13                   Fora Bolsonaro
# 96   2022-12-13                      Infiltrados
# 97   2022-12-13                        Patriotas
# 98   2022-12-13                      Terroristas
# 99   2022-12-14                          Faz o L
# 100  2022-12-29                        Faltam 72
# 101  2022-12-30                 ACABOU BOLSONARO
# 102  2022-12-30                      JAIR EMBORA
# 103  2022-12-30                             Lula

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(pd.DataFrame(dates_n_terms['search_terms'].value_counts()))
# Out:
#                                  count
# search_terms
# Eduardo Bolsonaro                    3
# ORÇAMENTO SECRETO NÃO              3
# BOLSONARO NÃO TRABALHA              2
# NÓS VENCEMOS                        2
# #LulaPresidente1️⃣3️⃣                2
# #LulaNo1ºTurno                       2
# Infiltrados                          2
# CAPES                                2
# #PagueMinhaBolsa                     2
# Faz o L                              2
# PERDEU MANÉ                         2
# Deu 22                               1
# EU AUTORIZO                          1
# 4  Em 3 anos e meio Bolsonaro trabalhou menos de ...      Edu64986869
#
#                                            user_info  has_mention mentions  \
# 0  {'id': 721831120120188928, 'name': 'Carlos Zit...        False     None
# 1  {'id': 87421436, 'name': 'Marcos Til', 'descri...        False     None
# 2  {'id': 1535023761241657351, 'name': 'Patriotis...        False     None
# 3  {'id': 1090045777395761154, 'name': 'desestres...        False     None
# 4  {'id': 1521688957720965120, 'name': 'Edu', 'de...        False     None
#
#    is_reply reply_to  is_quote quoted_from  is_retweet  \
# 0     False     None     False        None        True
# 1     False     None     False        None        True
# 2     False     None     False        None        True
# 3     False     None     False        None        True
# 4     False     None     False        None        True
#
#                                       retweeted_from hashtags
# 0  {'user': 'tesoureiros', 'user_id': 10714084365...     None
# 1  {'user': 'detremura', 'user_id': 102826672, 't...     None
# 2  {'user': 'ThiagoResiste', 'user_id': 127077402...     None
# 3  {'user': 'PedroRonchi2', 'user_id': 1097073004...     None
# 4  {'user': 'ThiagoResiste', 'user_id': 127077402...     None

# %%
file_example.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21380 entries, 0 to 21379
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_at      21380 non-null  object
#  1   tweet_id        21380 non-null  int64
#  2   tweet_content   21380 non-null  object
#  3   user            21380 non-null  object
#  4   user_info       21380 non-null  object
#  5   has_mention     21380 non-null  bool
#  6   mentions        3477 non-null   object
#  7   is_reply        21380 non-null  bool
#  8   reply_to        2686 non-null   object
#  9   is_quote        21380 non-null  bool
#  10  quoted_from     1348 non-null   object
#  11  is_retweet      21380 non-null  bool
#  12  retweeted_from  16312 non-null  object
#  13  hashtags        1114 non-null   object
# dtypes: bool(4), int64(1), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# ### __Quantitative Analysis__

# %% [markdown]
# #### __Textual Preprocessing__
#
#
#
# - URL removal
# - Mention removal (@user)
# - Hashtags removal (#removal)
# - Punctuation removal
# - Emoji removal
# - Removing unwanted white spaces
#     - Trailing spaces
#     - Multiple spaces
#     - Line breaks
# - Text Normalization
#     - Lowercase
#     - Stopwords removal

# %%
import warnings; warnings.simplefilter('ignore')

tweets = pd.DataFrame()
users = pd.Series()
tweets_total = 0

for file in file_list:
    df = pd.read_parquet(os.path.join(DATA_PATH, file))
    df['created_at'] = pd.to_datetime(df['created_at'])
    df['created_at'] = df['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S')
    users = pd.concat([users, df['user']], ignore_index=True)
    tweets_total += df.shape[0]
    tweets = pd.concat([tweets, df], ignore_index=True)
    users.drop_duplicates(keep='first', inplace=True, ignore_index=True)

tweets['preproc_tweet'] = tweets['tweet_content'].map(lambda x: pp.preprocess_text(x))
tweets_unique = tweets['preproc_tweet'].unique().shape[0]
users_unique = users.shape[0]

display(pd.DataFrame(
    index = ['tweets_total', 'tweets_unique'],
    data = [tweets_total, tweets_unique],
    columns = ['amount']
))
# Out:
#                 amount
# tweets_total   7015186
# tweets_unique   948982

# %%
print(f'Total number of users: {users.shape[0]}')
# Out:
# Total number of users: 951602

# %%
dates = dates_n_terms['date'].unique()
dates.shape
# Out:
# (36,)

# %%
days = {}
terms = {}

# %%
for day in dates:
    day_tweets = tweets.loc[tweets['created_at'].str.startswith(day)]
    day_terms = dates_n_terms.loc[dates_n_terms['date']==day]
    number_tweets = day_tweets.shape[0]
    numer_tweets_unique = day_tweets['preproc_tweet'].unique().shape[0]
    number_users = day_tweets['user'].unique().shape[0]
    number_terms = day_terms.shape[0]
    days[day] = {
        'number_of_tweets': number_tweets,
        'number_of_unique_tweets': numer_tweets_unique,
        'number_of_users': number_users,
        'number_of_terms': number_terms
    }

# %%
daily_status = pd.DataFrame.from_dict(days, orient='index')
daily_status
# Out:
#             number_of_tweets  number_of_unique_tweets  number_of_users  \
# 2022-08-01             14455                     1104             6294
# 2022-08-09              4010                      460             2119
# 2022-08-22            102457                    31969            44557
# 2022-08-25             26918                    10066            19784
# 2022-08-28             25436                     7731            12345
# 2022-09-23            122480                    19072            47420
# 2022-09-24             70752                    23020            27642
# 2022-09-25             29911                     6718            16350
# 2022-09-26             10694                     1835             6413
# 2022-09-28             20652                     9604             8406
# 2022-10-30            741039                    88690           265770
# 2022-10-31             35404                    13835            28171
# 2022-11-04            430578                    14801            85702
# 2022-11-06             36418                     2564            15254
# 2022-11-14             26389                     3215            11106
# 2022-11-15            263300                    22595            85963
# 2022-11-16            268376                    27241           101562
# 2022-11-17             47937                     5923            28636
# 2022-11-18             84512                     5763            32773
# 2022-11-19             56411                     3377            19459
# 2022-11-22            129840                     8660            43927
# 2022-11-23            185109                    30363            82800
# 2022-11-24            293479                    36736           103918
# 2022-11-28            117622                     8807            53301
# 2022-11-29            167156                    12250            72080
# 2022-11-30            133938                    14389            54046
# 2022-12-02             30740                     2279            17283
# 2022-12-06             46069                     5538            17466
# 2022-12-07            115613                    10403            45164
# 2022-12-08             13418                     1499             8214
# 2022-12-11             23459                     2714            14353
# 2022-12-12            515966                    54402           124468
# 2022-12-13           1412089                   183449           203648
# 2022-12-14            108296                    23618            49907
# 2022-12-29             12365                     1085            10948
# 2022-12-30            243360                    60278           117923
#
#             number_of_terms
# 2022-08-01                1
# 2022-08-09                1
# 2022-08-22                4
# 2022-08-25                3
# 2022-08-28                1
# 2022-09-23                3
# 2022-09-24                3
# 2022-09-25                3
# 2022-09-26               12
# 2022-09-28                1
# 2022-10-30                3
# 2022-10-31                3
# 2022-11-04                4
# 2022-11-06                1
# 2022-11-14                2
# 2022-11-15                1
# 2022-11-16                1
# 2022-11-17                2
# 2022-11-18                3
# 2022-11-19                2
# 2022-11-22                3
# 2022-11-23                7
# 2022-11-24                1
# 2022-11-28                1
# 2022-11-29                1
# 2022-11-30                5
# 2022-12-02                1
# 2022-12-06                2
# 2022-12-07                3
# 2022-12-08                1
# 2022-12-11                2
# 2022-12-12               13
# 2022-12-13                5
# 2022-12-14                1
# 2022-12-29                1
# 2022-12-30                3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter

# Set dark theme with grid
sns.set_theme(style="darkgrid", context="notebook", palette="deep")

# Reset index to get the date as a column
daily_status_reset = daily_status.reset_index().rename(columns={'index': 'date'})

fig, axes = plt.subplots(2, 1, figsize=(14, 10), sharex=True)

# First plot: number_of_tweets
sns.lineplot(
    data=daily_status_reset,
    x='date',
    y='number_of_tweets',
    marker='o',
    ax=axes[0]
)
axes[0].set_title('Number of Tweets per Day')
axes[0].set_ylabel('Number of Tweets')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

# Second plot: number_of_users
sns.lineplot(
    data=daily_status_reset,
    x='date',
    y='number_of_users',
    marker='o',
    ax=axes[1]
)
axes[1].set_title('Number of Users per Day')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Number of Users')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('../figs/2022_tweets_users_time_series.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
daily_status.mean()
# Out:
# number_of_tweets           165740.222222
# number_of_unique_tweets     21001.472222
# number_of_users             52365.888889
# number_of_terms                 2.888889
# dtype: float64

# %%
daily_status.max()
# Out:
# number_of_tweets           1412089
# number_of_unique_tweets     183449
# number_of_users             265770
# number_of_terms                 13
# dtype: int64

# %%
# Set dark theme with grid
sns.set_theme(style="darkgrid", context="notebook", palette="deep")

# Reset index to get the date as a column
daily_status_reset = daily_status.reset_index().rename(columns={'index': 'date'})

plt.figure(figsize=(14, 8))
ax = sns.barplot(
    data=daily_status_reset,
    x='date',
    y='number_of_terms',
    color='tab:blue'
)
plt.title('Number of Terms per Day')
plt.xlabel('Date')
plt.ylabel('Number of Terms')
plt.xticks(rotation=45, ha='right')
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

# Add values on top of bars
for p in ax.patches:
    height = p.get_height()
    if not pd.isna(height):
        ax.annotate(f'{int(height)}',
                    (p.get_x() + p.get_width() / 2, height),
                    ha='center', va='bottom', fontsize=9, color='black', fontweight='bold')

plt.tight_layout()
plt.savefig('../figs/2022_terms_time_series.png', dpi=300, bbox_inches='tight') 
plt.show()

# %%
file_list
# Out:
# ['2022-08-01-BOLSONARO NÃO TRABALHA.parquet',
#  '2022-08-09-NÃO VOTE EM RACISTA.parquet',
#  '2022-08-22-#BolsonaroNoJN.parquet',
#  '2022-08-22-#Eleicoes2022.parquet',
#  '2022-08-22-#ForaBolsonaro.parquet',
#  '2022-08-22-#GloboLixo.parquet',
#  '2022-08-25-#LADRAONOJN.parquet',
#  '2022-08-25-BOBO DA CORTE.parquet',
#  '2022-08-25-Faz o L.parquet',
#  '2022-08-28-#DebateNaBand.parquet',
#  '2022-09-23-DINHEIRO VIVO.parquet',
#  '2022-09-23-Faltam 9.parquet',
#  '2022-09-23-SÓ CIRO VENCE LULA.parquet',
#  '2022-09-24-#DebateNoSBT.parquet',
#  '2022-09-24-BOLSONARO CORRUPTO.parquet',
#  '2022-09-24-MEU VOTO NÃO ANISTIA BANDIDO.parquet',
#  '2022-09-25-#EsseÉMeuVoto.parquet',
#  '2022-09-25-#LulaNo1ºTurno.parquet',
#  '2022-09-25-Faltam 7.parquet',
#  '2022-09-26-#BrasilDaEsperança.parquet',
#  '2022-09-26-#BrasilVota22.parquet',
#  '2022-09-26-#CiroManifestoANacao.parquet',
#  '2022-09-26-#CiroNoFlow.parquet',
#  '2022-09-26-#LulaNo1ºTurno.parquet',
#  '2022-09-26-#TiraGomes.parquet',
#  '2022-09-26-AGORA É LULA.parquet',
#  '2022-09-26-BRASIL RESISTE.parquet',
#  '2022-09-26-Bolsonaro 31%.parquet',
#  '2022-09-26-Faltam 6.parquet',
#  '2022-09-26-LULA NO PRIMEIRO TURNO.parquet',
#  '2022-09-26-Lula 48%.parquet',
#  '2022-09-28-#DebateNaGlobo.parquet',
#  '2022-10-30-#BolsonaroReeleito2️⃣2️⃣.parquet',
#  '2022-10-30-#LulaPresidente1️⃣3️⃣.parquet',
#  '2022-10-30-Polícia Rodoviária Federal.parquet',
#  '2022-10-31-#LulaPresidente1️⃣3️⃣.parquet',
#  '2022-10-31-Apertei 13.parquet',
#  '2022-10-31-DEIXEM O NORDESTE VOTAR.parquet',
#  '2022-11-04-400 BILHÕES.parquet',
#  '2022-11-04-BOLSONARO QUEBROU O BRASIL.parquet',
#  '2022-11-04-JAIR QUEBROU O BRASIL.parquet',
#  '2022-11-04-Rombo de 400.parquet',
#  '2022-11-06-NÓS VENCEMOS.parquet',
#  '2022-11-14-#STFVergonhaMundial.parquet',
#  '2022-11-14-BOLSONARO NÃO TRABALHA.parquet',
#  '2022-11-15-PERDEU MANÉ.parquet',
#  '2022-11-16-PERDEU MANÉ.parquet',
#  '2022-11-17-BOLSONARO LADRÃO.parquet',
#  '2022-11-17-ORÇAMENTO SECRETO NÃO.parquet',
#  '2022-11-18-#Caminhoneiros.parquet',
#  '2022-11-18-APOIO LULA.parquet',
#  '2022-11-18-QG DO GOLPE.parquet',
#  '2022-11-19-BRAGA NETO NA CADEIA.parquet',
#  '2022-11-19-RENUNCIA BOLSONARO.parquet',
#  '2022-11-22-#BolsonaroReeleito.parquet',
#  '2022-11-22-Bolsonaro 51%.parquet',
#  '2022-11-22-O LULA TÁ ELEITO.parquet',
#  '2022-11-23-Alexandre de Morais.parquet',
#  '2022-11-23-Artigo 142.parquet',
#  '2022-11-23-Deu 22.parquet',
#  '2022-11-23-EU AUTORIZO.parquet',
#  '2022-11-23-É 22.parquet',
#  '2022-11-23-Faz o 22.parquet',
#  '2022-11-23-Xandão.parquet',
#  '2022-11-24-#EuAutorizoPresidente.parquet',
#  '2022-11-28-Eduardo Bolsonaro.parquet',
#  '2022-11-29-Eduardo Bolsonaro.parquet',
#  '2022-11-30-Bananinha.parquet',
#  '2022-11-30-Eduardo Bolsonaro.parquet',
#  '2022-11-30-HAARP.parquet',
#  '2022-11-30-JAIR SAQUEOU O BRASIL.parquet',
#  '2022-11-30-Paquita da Ditadura.parquet',
#  '2022-12-02-ORÇAMENTO SECRETO NÃO.parquet',
#  '2022-12-06-#PagueMinhaBolsa.parquet',
#  '2022-12-06-CAPES.parquet',
#  '2022-12-07-#PagueMinhaBolsa.parquet',
#  '2022-12-07-CAPES.parquet',
#  '2022-12-07-ORÇAMENTO SECRETO NÃO.parquet',
#  '2022-12-08-BOLSONARO INIMIGO DA EDUCAÇÃO.parquet',
#  '2022-12-11-DIPLOMAÇÃO DO LULA.parquet',
#  '2022-12-11-Votei 22.parquet',
#  '2022-12-12-#DiplomacaoDoLula.parquet',
#  '2022-12-12-#LulaEoBrasilSubindoARampa.parquet',
#  '2022-12-12-Armação.parquet',
#  '2022-12-12-Brasília.parquet',
#  '2022-12-12-Cacique.parquet',
#  '2022-12-12-Capitólio.parquet',
#  '2022-12-12-Infiltrados.parquet',
#  '2022-12-12-Índio.parquet',
#  '2022-12-12-LULA PRESIDENTE.parquet',
#  '2022-12-12-Manifestantes.parquet',
#  '2022-12-12-NÓS VENCEMOS.parquet',
#  '2022-12-12-Polícia Federal.parquet',
#  '2022-12-12-bolsonaristas.parquet',
#  '2022-12-13-Bolsonaristas.parquet',
#  '2022-12-13-Fora Bolsonaro.parquet',
#  '2022-12-13-Infiltrados.parquet',
#  '2022-12-13-Patriotas.parquet',
#  '2022-12-13-Terroristas.parquet',
#  '2022-12-14-Faz o L.parquet',
#  '2022-12-29-Faltam 72.parquet',
#  '2022-12-30-ACABOU BOLSONARO.parquet',
#  '2022-12-30-JAIR EMBORA.parquet',
#  '2022-12-30-Lula.parquet']

# %%
terms = {}

for term in dates_n_terms['search_terms']:
    term_tweets = pd.DataFrame()
    days_count = 0
    for file in file_list:
        if file[11:-8] == term:
            days_count+=1
            df = pd.read_parquet(os.path.join(DATA_PATH,file))
            term_tweets = pd.concat([term_tweets, df], ignore_index=True)
    term_tweets.drop_duplicates(keep='first', inplace=True, ignore_index=True)
    term_tweets['preproc_tweet'] = term_tweets['tweet_content'].map(lambda x: pp.preprocess_text(x))
    number_tweets = term_tweets.shape[0]
    number_tweets_unique = term_tweets['preproc_tweet'].unique().shape[0]
    number_users = term_tweets['user'].unique().shape[0]
    terms[term] = {
        'number_of_tweets': number_tweets,
        'number_of_unique_tweets': number_tweets_unique,
        'number_of_users': number_users,
        'number_of_days': days_count
    }

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(pd.DataFrame(terms).T)
# Out:
#                                  number_of_tweets  number_of_unique_tweets  \
# BOLSONARO NÃO TRABALHA                     39924                     3224
# NÃO VOTE EM RACISTA                        15690                      990
# #BolsonaroNoJN                             149347                    22834
# #Eleicoes2022                               76492                    10127
# #ForaBolsonaro                              81312                    29764
# #GloboLixo                                 339422                    83667
# #LADRAONOJN                                 41126                     6499
# BOBO DA CORTE                              100333                    20379
# Faz o L                                     84911                    19902
# #DebateNaBand                              168651                    66584
# DINHEIRO VIVO                               38846                     4717
# Faltam 9                                     1636                      460
# SÓ CIRO VENCE LULA                         20113                     3381
# #DebateNoSBT                                34797                    15105
# BOLSONARO CORRUPTO                            988                      528
# MEU VOTO NÃO ANISTIA BANDIDO                6577                      927
# #EsseÉMeuVoto                               3203                     1246
# #LulaNo1ºTurno                              15678                     5288
# Faltam 7                                     2488                      752
# #BrasilDaEsperança                         25627                     1815
# #BrasilVota22                                2828                      557
# #CiroManifestoANacao                          100                       51
# #CiroNoFlow                                   430                      114

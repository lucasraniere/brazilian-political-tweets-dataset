# %%
import sys
sys.path.insert(1, '../')

import pandas as pd
from source import preprocess as pp
from source import utils
import os

DATA_PATH = '../data/2022-brazilian-presidential/'
file_list = [file for file in os.listdir(DATA_PATH) if file.startswith('2022-')]
file_list.sort()

# %%
pd.read_parquet(os.path.join(DATA_PATH, file_list[1]))
# Out:
#                 created_at             tweet_id  \
# 0      2022-08-12 02:51:44  1557922754606907394
# 1      2022-08-12 02:50:35  1557922465577406464
# 2      2022-08-12 02:47:03  1557921579039920131
# 3      2022-08-12 02:41:36  1557920205183090691
# 4      2022-08-12 02:25:26  1557916137417019395
# ...                    ...                  ...
# 15685  2022-08-09 21:32:46  1557117710068322308
# 15686  2022-08-09 21:32:44  1557117700970872832
# 15687  2022-08-09 21:32:35  1557117664933330944
# 15688  2022-08-09 21:31:53  1557117487526952960
# 15689  2022-08-09 21:31:39  1557117429028896773
#
#                                            tweet_content          user  \
# 0      Intolerância religiosa contra religiões de mat...    SeibelArno
# 1                    @ThiagoResiste Nao vote em racista.   mario_sesta
# 2      NÃO VOTE EM RACISTA! \n\n “Um povo que não con...      Soange20
# 3      As religiões africanas são parte fundamental d...  monicasouzal
# ...

# %%
for file in file_list:
    df = pd.read_parquet(os.path.join(DATA_PATH,file))
    if 'Unnamed: 0' in df.columns:
        print(f'Processing file: {file}')
        # df.drop(columns=['Unnamed: 0'], inplace=True)
        # df.to_parquet(os.path.join(DATA_PATH,file), index=False)

# %%
for file in file_list:
    print(f'Processing file: {file}')
    df = pd.read_parquet(os.path.join(DATA_PATH,file))
    df['created_at'] = df['created_at'].map(lambda x: utils.convert_date(x))
    df.to_parquet(os.path.join(DATA_PATH,file), index=False)
# Out:
# Processing file: 2022-08-01-BOLSONARO NÃO TRABALHA.parquet
# Processing file: 2022-08-09-NÃO VOTE EM RACISTA.parquet
# Processing file: 2022-08-22-#BolsonaroNoJN.parquet
# Processing file: 2022-08-22-#Eleicoes2022.parquet
# Processing file: 2022-08-22-#ForaBolsonaro.parquet
# Processing file: 2022-08-22-#GloboLixo.parquet
# Processing file: 2022-08-25-#LADRAONOJN.parquet
# Processing file: 2022-08-25-BOBO DA CORTE.parquet
# Processing file: 2022-08-25-Faz o L.parquet
# Processing file: 2022-08-28-#DebateNaBand.parquet
# Processing file: 2022-09-23-DINHEIRO VIVO.parquet
# Processing file: 2022-09-23-Faltam 9.parquet
# Processing file: 2022-09-23-SÓ CIRO VENCE LULA.parquet
# Processing file: 2022-09-24-#DebateNoSBT.parquet
# Processing file: 2022-09-24-BOLSONARO CORRUPTO.parquet
# Processing file: 2022-09-24-MEU VOTO NÃO ANISTIA BANDIDO.parquet
# Processing file: 2022-09-25-#EsseÉMeuVoto.parquet
# Processing file: 2022-09-25-#LulaNo1ºTurno.parquet
# ...

# %%
pd.read_parquet(os.path.join(DATA_PATH,'2022-10-30-#BolsonaroReeleito2️⃣2️⃣.parquet')).head()
# Out:
#    Unnamed: 0           created_at             tweet_id  \
# 0           0  2022-10-31 02:58:48  1586915562671718402
# 1           1  2022-10-31 02:58:33  1586915499383955457
# 2           2  2022-10-31 02:58:20  1586915446833516544
# 3           3  2022-10-31 02:58:13  1586915418526081024
# 4           4  2022-10-31 02:58:05  1586915384380342273
#
#                                        tweet_content             user  \
# 0  Faz o L, eles disseram...\n#BolsonaroReeleito2...     eliasgaddini
# 1  Minha bandeira jamais será vermelha  #Bolsonar...       JuneilsonC
# 2  Votei 22. Prefiro ver uma mulher armada que um...  Reginal49984512
# 3  SC em fúria, é o fim da petralha \nParalisação...       marciaAbe2
# 4  Petistas sendo Petistas, fazem questão de faze...      dudusouzajr
#
#                                            user_info  has_mention mentions  \
# 0  {'id': 228143946, 'name': 'Elias 🇧🇷🇧🇷🇮🇹🇮🇹', 'd...        False     None
# ...

# %%
pd.read_parquet(os.path.join(DATA_PATH,'2022-10-30-#BolsonaroReeleito2️⃣2️⃣.parquet')).head()
# Out:
#             created_at             tweet_id  \
# 0  2022-10-31 02:58:48  1586915562671718402
# 1  2022-10-31 02:58:33  1586915499383955457
# 2  2022-10-31 02:58:20  1586915446833516544
# 3  2022-10-31 02:58:13  1586915418526081024
# 4  2022-10-31 02:58:05  1586915384380342273
#
#                                        tweet_content             user  \
# 0  Faz o L, eles disseram...\n#BolsonaroReeleito2...     eliasgaddini
# 1  Minha bandeira jamais será vermelha  #Bolsonar...       JuneilsonC
# 2  Votei 22. Prefiro ver uma mulher armada que um...  Reginal49984512
# 3  SC em fúria, é o fim da petralha \nParalisação...       marciaAbe2
# 4  Petistas sendo Petistas, fazem questão de faze...      dudusouzajr
#
#                                            user_info  has_mention mentions  \
# 0  {'id': 228143946, 'name': 'Elias 🇧🇷🇧🇷🇮🇹🇮🇹', 'd...        False     None
# 1  {'id': 1141286046803607553, 'name': 'Juneilson...        False     None
# ...
